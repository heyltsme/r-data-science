# %%
# 1. Create a local folder called 'renv' (or any name) in your current workspace
dir.create("rtemp_packages", showWarnings = FALSE)

# 2. Install the packages into THAT specific folder
install.packages(c("ggthemes", "palmerpenguins"), lib = "rtemp_packages", repos = "https://cran.rstudio.com/")

# 3. Tell R to look in that folder for your libraries
.libPaths(c("rtemp_packages", .libPaths()))

# %%
install.packages(c("ggthemes","palmerpenguins"))
# Out:
# Installing packages into ‘/workspaces/r-data-science/rtemp_packages’
# (as ‘lib’ is unspecified)

# %%
library(tidyverse, ggthemes)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
library(palmerpenguins)
# Out:
# Attaching package: ‘palmerpenguins’
#
#
# The following objects are masked from ‘package:datasets’:
#
#     penguins, penguins_raw

# %%
glimpse(penguins)
# Out:
# Rows: 344
# Columns: 8
# $ species           <fct> Adelie, Adelie, Adelie, Adelie, Adelie, Adelie, Adel…
# $ island            <fct> Torgersen, Torgersen, Torgersen, Torgersen, Torgerse…
# $ bill_length_mm    <dbl> 39.1, 39.5, 40.3, NA, 36.7, 39.3, 38.9, 39.2, 34.1, …
# $ bill_depth_mm     <dbl> 18.7, 17.4, 18.0, NA, 19.3, 20.6, 17.8, 19.6, 18.1, …
# $ flipper_length_mm <int> 181, 186, 195, NA, 193, 190, 181, 195, 193, 190, 186…
# $ body_mass_g       <int> 3750, 3800, 3250, NA, 3450, 3650, 3625, 4675, 3475, …
# $ sex               <fct> male, female, female, NA, female, male, female, male…
# $ year              <int> 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007, 2007…

# %%
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g)
) +
  geom_point(mapping = aes(color = species, shape = species)) +
  geom_smooth(method = "lm")
# Out:
# `geom_smooth()` using formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
nrow(penguins)
# Out:
# [1] 344

# %%
ggplot(
    data = penguins,
    mapping = aes(x = bill_length_mm, y = bill_depth_mm)
) +
    geom_point(mapping = aes(color = species))
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
ggplot(
    data = penguins,
    mapping = aes(x = species, y = bill_depth_mm)
) +
    geom_boxplot(mapping = aes(color = species))
# Out:
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range
# (`stat_boxplot()`).”
# plot without title

# %%
ggplot(
    data = penguins,
    mapping = aes(x = bill_length_mm, y = bill_depth_mm)
) +
    geom_point(mapping = aes(color = species), na.rm = TRUE)
# Out:
# plot without title

# %%
ggplot(
    data = penguins,
    mapping = aes(x = bill_length_mm, y = bill_depth_mm)
) +
    geom_point(mapping = aes(color = species), na.rm = TRUE) +
labs(
    title = "Data come from the palmerpenguins package."
  )
# Out:
# plot without title

# %%
ggplot(
    data = penguins,
    mapping = aes(x = flipper_length_mm, y = body_mass_g)
) +
    geom_point(mapping = aes(color = bill_depth_mm), na.rm = TRUE) +
    geom_smooth(na.rm = TRUE) +
labs(
    x = "flipper_length_mm",
    y = "body_mass_g",
    color = "bill_depth_mm"
  )
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %%
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g, color = island)
) +
  geom_point() +
  geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
ggplot(
  data = penguins,
  mapping = aes(x = flipper_length_mm, y = body_mass_g)
) +
  geom_point() +
  geom_smooth()

ggplot() +
  geom_point(
    data = penguins,
    mapping = aes(x = flipper_length_mm, y = body_mass_g)
  ) +
  geom_smooth(
    data = penguins,
    mapping = aes(x = flipper_length_mm, y = body_mass_g)
  )
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_smooth()`).”
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title
# plot without title

# %%
ggplot(penguins, aes(y = species)) +
geom_bar()
# Out:
# plot without title

# %%
ggplot(penguins, aes(x = species)) +
  geom_bar(color = "red")

ggplot(penguins, aes(x = species)) +
  geom_bar(fill = "red")
# Out:
# plot without title
# plot without title

# %%
ggplot(penguins, aes(y = flipper_length_mm)) +
geom_histogram(bins = 20, fill="blue")
# Out:
# Warning message:
# “Removed 2 rows containing non-finite outside the scale range (`stat_bin()`).”
# plot without title

# %%
ggplot(data = diamonds, mapping = aes(x = carat)) +
geom_histogram(bins = 100)
# Out:
# plot without title

# %%
?mpg
# Out:
# mpg                  package:ggplot2                   R Documentation
#
# s
#
# n:
#
#      This dataset contains a subset of the fuel economy data that the
#      EPA makes available on <https://fueleconomy.gov/>. It contains
#      only models which had a new release every year between 1999 and
#      2008 - this was used as a proxy for the popularity of the car.
#
# e:
#
#      mpg
#
# t:
#
#      A data frame with 234 rows and 11 variables:
#
#      manufacturer manufacturer name
#
#      model model name
#
#      displ engine displacement, in litres
#
#      year year of manufacture
#
#      cyl number of cylinders
#
#      trans type of transmission
#
#      drv the type of drive train, where f = front-wheel drive, r = rear
#           wheel drive, 4 = 4wd
#
#      cty city miles per gallon
#
#      hwy highway miles per gallon
#
#      fl fuel type
#
#      class "type" of car

# %%
ggplot(data = mpg, aes(x = hwy, y = displ)) +
geom_point()
# Out:
# plot without title

# %%
ggplot(data = mpg, aes(x = hwy, y = displ)) +
geom_point(aes(color = year))
# Out:
# plot without title

# %%
ggplot(data = mpg, aes(x = hwy, y = displ)) +
geom_point(aes(size = year))
# Out:
# plot without title

# %%
ggplot(data = mpg, aes(x = hwy, y = displ)) +
geom_point(aes(size = year, color = cty))
# Out:
# plot without title

# %%
ggplot(data = mpg, aes(x = hwy, y = displ)) +
geom_point(aes(size = year, color = cty, shape = drv))
# Out:
# plot without title

# %%
ggplot(data = mpg, aes(x = hwy, y = displ)) +
geom_point(aes(color = cty, size = cty))
# Out:
# plot without title

# %%
ggplot(data = penguins, aes(x = bill_depth_mm, y = bill_length_mm, color = species)) +
geom_point()
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
ggplot(data = penguins, aes(x = bill_depth_mm, y = bill_length_mm, color = species)) +
geom_point() +
facet_wrap(~species)
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
ggplot(
  data = penguins,
  mapping = aes(
    x = bill_length_mm, y = bill_depth_mm, 
    color = species, shape = species
  )
) +
  geom_point()
# Out:
# Warning message:
# “Removed 2 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
ggplot(penguins, aes(x = island, fill = species)) +
  geom_bar(position = "fill")
ggplot(penguins, aes(x = species, fill = island)) +
  geom_bar(position = "fill")
# Out:
# plot without title
# plot without title
